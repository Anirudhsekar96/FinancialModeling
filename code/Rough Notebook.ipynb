# %%
import sys
print(sys.version)
# Out:
# 3.5.5 |Anaconda, Inc.| (default, May 13 2018, 21:12:35)
# [GCC 7.2.0]

# %%
import numpy as np 
import pandas as pd

# %%
cars_df              = pd.read_csv("../data/Cars_.csv") 
cleaned_combined_df  = pd.read_csv("../data/cleaned_combined.csv", index_col=0)
data_df              = pd.read_csv("../data/dataset0302.csv")

org_sales_per_quarter_df = pd.read_excel("../data/Original_Data/Automative Sales per quarter in North America.xlsx")
org_index_df             = pd.read_excel("../data/Original_Data/indexes for automatovie sector.xlsx")
org_marketshare_df       = pd.read_excel("../data/Original_Data/Market share per quarter for major automative industry.xlsx")
org_ratio_df             = pd.read_excel("../data/Original_Data/ratios for automotive sector players.xlsx")
org_saartot_df           = pd.read_excel("../data/Original_Data/saartot-2000-2019.xlsx",sheet_name="Sheet1",header=None)

# %%
cars_df.head()
# Out:
#        date   Audi    BMW    Mini  Mercedes Benz  Mitsubishi Fuso       FCA  \
# 0  Jan 2019  14253  18102  2457.0          23721              0.0  136082.0
# 1  Dec 2018  22765  34357  2797.0          36132              4.0  196520.0
# 2  Nov 2018  17082  28330  3528.0          32879              3.0  181310.0
# 3  Oct 2018  16056  23262  3166.0          31719              4.0  177391.0
# 4  Sep 2018  19319  25908  3461.0          30617              3.0  199819.0
#
#    Honda Group  Hyundai  Isuzu  ...    Mitsubishi  Nissan  Porsche  Subaru  \
# 0       106139    42020    265  ...          8708  100741   5419.0   46072
# 1       155115    65721    534  ...          8986  148720   4086.0   64541
# 2       120534    57499    415  ...          7688  110513   5673.0   56782
# 3       122182    53025    387  ...          8002  109962   4817.0   55394
# 4       132668    57359    415  ...          7705  122819   5102.0   57044
#
#      Tesla  Toyota Group  Volkswagen  Volvo  year  month
# ...

# %%
cleaned_combined_df.head()
# Out:
#   Manufaturer    Sales  Year Quarter  Index  Ratio
# 0     AUDI AG  14253.0  2019      Q1    NaN    NaN
# 1     AUDI AG  22765.0  2018      Q4    NaN    NaN
# 2     AUDI AG  17082.0  2018      Q4    NaN    NaN
# 3     AUDI AG  16056.0  2018      Q4    NaN    NaN
# 4     AUDI AG  19319.0  2018      Q3    NaN    NaN

# %%
cars_df.head()
# Out:
#        date   Audi    BMW    Mini  Mercedes Benz  Mitsubishi Fuso       FCA  \
# 0  Jan 2019  14253  18102  2457.0          23721              0.0  136082.0
# 1  Dec 2018  22765  34357  2797.0          36132              4.0  196520.0
# 2  Nov 2018  17082  28330  3528.0          32879              3.0  181310.0
# 3  Oct 2018  16056  23262  3166.0          31719              4.0  177391.0
# 4  Sep 2018  19319  25908  3461.0          30617              3.0  199819.0
#
#    Honda Group  Hyundai  Isuzu  ...    Mitsubishi  Nissan  Porsche  Subaru  \
# 0       106139    42020    265  ...          8708  100741   5419.0   46072
# 1       155115    65721    534  ...          8986  148720   4086.0   64541
# 2       120534    57499    415  ...          7688  110513   5673.0   56782
# 3       122182    53025    387  ...          8002  109962   4817.0   55394
# 4       132668    57359    415  ...          7705  122819   5102.0   57044
#
#      Tesla  Toyota Group  Volkswagen  Volvo  year  month
# ...

# %%
org_sales_per_quarter_df.head()
# Out:
#                       Description          Ticker Field ID     Field Mnemonic  \
# 0      By Geography ($M) - Toyota  7203 JP Equity    IS010     SALES_REV_TURN
# 1                   North America  7203 JP Equity    BI047  BICS_SEGMENT_DATA
# 2  By Geography ($M) - Volkswagen   VOW GR Equity    IS010     SALES_REV_TURN
# 3                   North America   VOW GR Equity    BI047  BICS_SEGMENT_DATA
# 4          By Geography ($M) - GM    GM US Equity    IS010     SALES_REV_TURN
#
#   Data State      2018 Q4      2018 Q3      2018 Q2      2018 Q1      2017 Q4  \
# 0    Dynamic  69206.03296  65578.04288  67484.94541  70002.28365  67379.55935
# 1    Dynamic  23606.33773  23341.73636  25255.14253  22728.04798  24422.56068
# 2    Dynamic  69915.57964  64190.44523  72901.23101  71561.40746  70449.91328
# 3    Dynamic          NaN  11237.97940  10723.74974  10735.00995  12158.96394
# 4    Dynamic  38399.00000  35791.00000  36760.00000  36099.00000  37715.00000
#
# ...

# %%
org_marketshare_df.head()
# Out:
#                           Description          Ticker Field ID Field Mnemonic  \
# 0        Global Vehicle Sales (units)             NaN      NaN            NaN
# 1  by Region/ Country of Sale (units)  AUTMTVSA Index      NaN            NaN
# 2                        Asia Pacific  AUTMASBS Index      NaN            NaN
# 3                           Australia  AUTMAUVS Index    PX385   INTERVAL_SUM
# 4                               China   CNVSTTL Index    PX385   INTERVAL_SUM
#
#   Data State    2019 Q1     2018 Q4     2018 Q3     2018 Q2     2018 Q1  \
# 0    Heading        NaN         NaN         NaN         NaN         NaN
# 1        Sum  4868119.0  16056166.0  15085594.0  16374572.0  20618349.0
# 2        Sum  3020556.0  10208093.0   8976171.0   9372976.0   9980596.0
# 3    Dynamic        NaN         NaN         NaN         NaN         NaN
# 4    Dynamic  2367278.0   7589411.0   6386536.0   6879927.0   7183073.0
#
# ...

# %%
org_index_df.head()
# Out:
#                                     Description          Ticker Field ID  \
# 0                                      T12M EPS             NaN      NaN
# 1                                       AUDI AG   NSU GR Equity    RR844
# 2                                  Avtovaz PJSC  AVAZ RM Equity    RR844
# 3                   Bayerische Motoren Werke AG   BMW GR Equity    RR844
# 4      Brilliance China Automotive Holdings Ltd  1114 HK Equity    RR844
#
#           Field Mnemonic Data State  2019 Q1   2018 Q4    2018 Q3    2018 Q2  \
# 0                    NaN    Average      NaN  4.365867   3.314020   3.198872
# 1  T12M_DIL_EPS_CONT_OPS    Dynamic      NaN       NaN        NaN        NaN
# 2  T12M_DIL_EPS_CONT_OPS    Dynamic      NaN       NaN   0.003483  -0.005844
# 3  T12M_DIL_EPS_CONT_OPS    Dynamic      NaN       NaN  14.871762  15.678870
# 4  T12M_DIL_EPS_CONT_OPS    Dynamic      NaN       NaN        NaN        NaN
#
# ...

# %%
org_ratio_df.head()
# Out:
#                        Description          Ticker Field ID Field Mnemonic  \
# 0                     Price Ratios             NaN      NaN            NaN
# 1                              P/E  BRAUTOCV Index      NaN            NaN
# 2                          AUDI AG   NSU GR Equity    RR900       PE_RATIO
# 3                     Avtovaz PJSC  AVAZ RM Equity    RR900       PE_RATIO
# 4      Bayerische Motoren Werke AG   BMW GR Equity    RR900       PE_RATIO
#
#   Data State     2019 Q1     2018 Q4     2018 Q3    2018 Q2    2018 Q1  \
# 0    Heading         NaN         NaN         NaN        NaN        NaN
# 1    Average   34.687064   36.354927   37.486505  16.321172  14.384378
# 2    Dynamic         NaN         NaN         NaN        NaN        NaN
# 3    Dynamic  496.563390  496.563390  479.175584        NaN        NaN
# 4    Dynamic    5.812445    5.624690    6.165679   5.872419   6.576656
#
#      ...        2006 Q3    2006 Q2    2006 Q1    2005 Q4    2005 Q3  \
# ...

# %%
org_saartot_df           = pd.read_excel("../data/Original_Data/saartot-2000-2019.xlsx",sheet_name="Sheet1",header=None)
org_saartot_df.drop([4],axis=1,inplace=True)
org_saartot_df.dropna(subset=[0],inplace=True)
print(len(org_saartot_df))
org_saartot_df = org_saartot_df.rename(index=str,columns={0:"Timestamp",1:"Value",2:"Absolute_change",3:"Percentage_change"})
org_saartot_df['Target'] = org_saartot_df["Absolute_change"].apply(lambda x: 1 if x>0 else 0)
y = org_saartot_df.Target
org_saartot_df.head()
# Out:
# 230
#    Timestamp  Value  Absolute_change  Percentage_change  Target
# 0 2019-02-28  16.56            -0.04            -0.0024       0
# 1 2019-01-31  16.60            -0.90            -0.0514       0
# 3 2018-12-31  17.50             0.10             0.0057       1
# 4 2018-11-30  17.40            -0.10            -0.0057       0
# 5 2018-10-31  17.50             0.10             0.0057       1

# %%
org_ratio_df
# Out:
#                                       Description              Ticker  \
# 0                                    Price Ratios                 NaN
# 1                                             P/E      BRAUTOCV Index
# 2                                         AUDI AG       NSU GR Equity
# 3                                    Avtovaz PJSC      AVAZ RM Equity
# 4                     Bayerische Motoren Werke AG       BMW GR Equity
# 5        Brilliance China Automotive Holdings Ltd      1114 HK Equity
# 6                                      BYD Co Ltd      1211 HK Equity
# 7             Chongqing Changan Automobile Co Ltd    200625 CH Equity
# 8                           Daihatsu Motor Co Ltd      7262 JP Equity
# 9                                      Daimler AG       DAI GR Equity
# 10                    Dongfeng Motor Group Co Ltd       489 HK Equity
# 11                                  DRB-Hicom Bhd       DRB MK Equity
# ...

# %%
cars_df["datetime"] = pd.to_datetime(cars_df['date'])
cars_df.head()
# Out:
#        date   Audi    BMW    Mini  Mercedes Benz  Mitsubishi Fuso       FCA  \
# 0  Jan 2019  14253  18102  2457.0          23721              0.0  136082.0
# 1  Dec 2018  22765  34357  2797.0          36132              4.0  196520.0
# 2  Nov 2018  17082  28330  3528.0          32879              3.0  181310.0
# 3  Oct 2018  16056  23262  3166.0          31719              4.0  177391.0
# 4  Sep 2018  19319  25908  3461.0          30617              3.0  199819.0
#
#    Honda Group  Hyundai  Isuzu    ...      Nissan  Porsche  Subaru    Tesla  \
# 0       106139    42020    265    ...      100741   5419.0   46072  18411.0
# 1       155115    65721    534    ...      148720   4086.0   64541  24712.0
# 2       120534    57499    415    ...      110513   5673.0   56782  16843.0
# 3       122182    53025    387    ...      109962   4817.0   55394  17851.0
# 4       132668    57359    415    ...      122819   5102.0   57044  15175.0
#
# ...

# %%
cars_df["month"] = cars_df['datetime'].dt.month
cars_df.head()
# Out:
#        date   Audi    BMW    Mini  Mercedes Benz  Mitsubishi Fuso       FCA  \
# 0  Jan 2019  14253  18102  2457.0          23721              0.0  136082.0
# 1  Dec 2018  22765  34357  2797.0          36132              4.0  196520.0
# 2  Nov 2018  17082  28330  3528.0          32879              3.0  181310.0
# 3  Oct 2018  16056  23262  3166.0          31719              4.0  177391.0
# 4  Sep 2018  19319  25908  3461.0          30617              3.0  199819.0
#
#    Honda Group  Hyundai  Isuzu    ...      Nissan  Porsche  Subaru    Tesla  \
# 0       106139    42020    265    ...      100741   5419.0   46072  18411.0
# 1       155115    65721    534    ...      148720   4086.0   64541  24712.0
# 2       120534    57499    415    ...      110513   5673.0   56782  16843.0
# 3       122182    53025    387    ...      109962   4817.0   55394  17851.0
# 4       132668    57359    415    ...      122819   5102.0   57044  15175.0
#
# ...

# %%
org_ratio_df[:1000]
# Out:
#                                       Description              Ticker  \
# 0                                    Price Ratios                 NaN
# 1                                             P/E      BRAUTOCV Index
# 2                                         AUDI AG       NSU GR Equity
# 3                                    Avtovaz PJSC      AVAZ RM Equity
# 4                     Bayerische Motoren Werke AG       BMW GR Equity
# 5        Brilliance China Automotive Holdings Ltd      1114 HK Equity
# 6                                      BYD Co Ltd      1211 HK Equity
# 7             Chongqing Changan Automobile Co Ltd    200625 CH Equity
# 8                           Daihatsu Motor Co Ltd      7262 JP Equity
# 9                                      Daimler AG       DAI GR Equity
# 10                    Dongfeng Motor Group Co Ltd       489 HK Equity
# 11                                  DRB-Hicom Bhd       DRB MK Equity
# ...

# %%
splits = ["PE_RATIO" ,
          "BEST_EST_PE_CUR_YR",
          "BEST_EST_PE_NXT_YR",
          "PX_TO_BOOK_RATIO",
          "PX_TO_TANG_BOOK_VAL_PER_SH",
          "CURRENT_PX_TO_FREE_CASH_FLOW",
          "PX_TO_SALES_RATIO",
          "EV_TO_T12M_EBITDA",
          "EV_TO_T12M_SALES",
          "EV_TO_MKT_CAP",
          "EV_TO_T12M_CASH_FLOW",
          "EV_TO_T12M_NET_INCOME",
          "EQY_DVD_YLD_IND",
          "EBIT_YIELD",
          "FREE_CASH_FLOW_YIELD",
          "T12_FCF_YIELD"      
         ]

PE_RATIO                       = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[0]]
BEST_EST_PE_CUR_YR             = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[1]]
BEST_EST_PE_NXT_YR             = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[2]]
PX_TO_BOOK_RATIO               = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[3]]
PX_TO_TANG_BOOK_VAL_PER_SH     = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[4]]
CURRENT_PX_TO_FREE_CASH_FLOW   = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[5]]
PX_TO_SALES_RATIO              = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[6]]
EV_TO_T12M_EBITDA              = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[7]]
EV_TO_T12M_SALES               = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[8]]
EV_TO_MKT_CAP                  = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[9]]
EV_TO_T12M_CASH_FLOW           = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[10]]
EV_TO_T12M_NET_INCOME          = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[11]]
EQY_DVD_YLD_IND                = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[12]]
EBIT_YIELD                     = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[13]]
FREE_CASH_FLOW_YIELD           = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[14]]
T12_FCF_YIELD                  = org_ratio_df[org_ratio_df["Field Mnemonic"] == splits[15]]

# %%
id_vars =  ["Description", "Ticker","Field Mnemonic","Data State","Field ID"]
val_vars= ['2019 Q1', '2018 Q4', '2018 Q3', '2018 Q2', '2018 Q1', '2017 Q4',
       '2017 Q3', '2017 Q2', '2017 Q1', '2016 Q4', '2016 Q3', '2016 Q2',
       '2016 Q1', '2015 Q4', '2015 Q3', '2015 Q2', '2015 Q1', '2014 Q4',
       '2014 Q3', '2014 Q2', '2014 Q1', '2013 Q4', '2013 Q3', '2013 Q2',
       '2013 Q1', '2012 Q4', '2012 Q3', '2012 Q2', '2012 Q1', '2011 Q4',
       '2011 Q3', '2011 Q2', '2011 Q1', '2010 Q4', '2010 Q3', '2010 Q2',
       '2010 Q1', '2009 Q4', '2009 Q3', '2009 Q2', '2009 Q1', '2008 Q4',
       '2008 Q3', '2008 Q2', '2008 Q1', '2007 Q4', '2007 Q3', '2007 Q2',
       '2007 Q1', '2006 Q4', '2006 Q3', '2006 Q2', '2006 Q1', '2005 Q4',
       '2005 Q3', '2005 Q2', '2005 Q1', '2004 Q4', '2004 Q3', '2004 Q2']

drop_cars = ['    Avtovaz PJSC',
             '    BYD Co Ltd',
             '    Brilliance China Automotive Holdings Ltd',
             '    Chongqing Changan Automobile Co Ltd',
             '    DRB-Hicom Bhd',
             '    Daihatsu Motor Co Ltd',
             '    Dongfeng Motor Group Co Ltd',
             '    FAW CAR Co Ltd',
             '    Ford Otomotiv Sanayi AS',
             '    GAZ PJSC',
             '    Geely Automobile Holdings Ltd',
             '    Great Wall Motor Co Ltd',
             '    Guangzhou Automobile Group Co Ltd',
             '    SAIC Motor Corp Ltd',
             '    Sanyang Motor Co Ltd',
             '    Sollers PJSC',
             '    Ssangyong Motor Co',
             '    Suzuki Motor Corp',
             '    Tata Motors Ltd',
             '    Tianjin Faw Xiali Automobile Co Ltd',
             '    Tofas Turk Otomobil Fabrikasi AS',
             '    Yulon Motor Co Ltd',
             '    Peugeot SA', 
             '    Renault SA'
            ]


PE_RATIO = pd.melt(PE_RATIO,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
BEST_EST_PE_CUR_YR = pd.melt(BEST_EST_PE_CUR_YR,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
BEST_EST_PE_NXT_YR = pd.melt(BEST_EST_PE_NXT_YR,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
PX_TO_BOOK_RATIO = pd.melt(PX_TO_BOOK_RATIO,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
PX_TO_TANG_BOOK_VAL_PER_SH = pd.melt(PX_TO_TANG_BOOK_VAL_PER_SH,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
CURRENT_PX_TO_FREE_CASH_FLOW = pd.melt(CURRENT_PX_TO_FREE_CASH_FLOW,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
PX_TO_SALES_RATIO = pd.melt(PX_TO_SALES_RATIO,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
EV_TO_T12M_EBITDA = pd.melt(EV_TO_T12M_EBITDA,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
EV_TO_T12M_SALES = pd.melt(EV_TO_T12M_SALES,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
EV_TO_MKT_CAP = pd.melt(EV_TO_MKT_CAP,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
EV_TO_T12M_CASH_FLOW = pd.melt(EV_TO_T12M_CASH_FLOW,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
EV_TO_T12M_NET_INCOME = pd.melt(EV_TO_T12M_NET_INCOME,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
EQY_DVD_YLD_IND = pd.melt(EQY_DVD_YLD_IND,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
EBIT_YIELD = pd.melt(EBIT_YIELD,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
FREE_CASH_FLOW_YIELD = pd.melt(FREE_CASH_FLOW_YIELD,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)
T12_FCF_YIELD = pd.melt(T12_FCF_YIELD,id_vars=id_vars,value_vars=val_vars).drop(["Ticker","Field Mnemonic","Data State","Field ID"],axis=1).pivot(index="variable",columns="Description",values=["value"])["value"].drop(drop_cars,axis=1)

# %%
dfs_to_be_merged = [PE_RATIO,
                   BEST_EST_PE_CUR_YR,
                   BEST_EST_PE_NXT_YR,
                   PX_TO_BOOK_RATIO,
                   PX_TO_TANG_BOOK_VAL_PER_SH,
                   CURRENT_PX_TO_FREE_CASH_FLOW,
                   PX_TO_SALES_RATIO,
                   EV_TO_T12M_EBITDA,
                   EV_TO_T12M_SALES,
                   EV_TO_MKT_CAP,
                   EV_TO_T12M_CASH_FLOW,
                   EV_TO_T12M_NET_INCOME,
                   EQY_DVD_YLD_IND,
                   EBIT_YIELD,
                   FREE_CASH_FLOW_YIELD,
                   T12_FCF_YIELD  
                  ]

merged_df_ratios = pd.concat(dfs_to_be_merged,axis=1)
merged_df_ratios.head()
# Out:
# Description      AUDI AG      Bayerische Motoren Werke AG      Daimler AG  \
# variable
# 2004 Q2              NaN                        11.882353             NaN
# 2004 Q3              NaN                        10.659164       13.498982
# 2004 Q4              NaN                         9.969970       14.275304
# 2005 Q1              NaN                        10.513514       14.794872
# 2005 Q2              NaN                        11.369369       13.440000
#
# Description      Fiat Chrysler Automobiles NV      Ford Motor Co  \
# variable
# 2004 Q2                                   NaN           6.561845
# 2004 Q3                                   NaN           5.564356
# 2004 Q4                                   NaN           6.938389
# 2005 Q1                                   NaN           6.950920
# 2005 Q2                                   NaN           6.872483
#
# Description      General Motors Co      Honda Motor Co Ltd  \
# variable
# ...

# %%
PE_RATIO.columns
# Out:
# Index(['    AUDI AG', '    Bayerische Motoren Werke AG', '    Daimler AG',
#        '    Fiat Chrysler Automobiles NV', '    Ford Motor Co',
#        '    General Motors Co', '    Honda Motor Co Ltd',
#        '    Hyundai Motor Co', '    Kia Motors Corp', '    Mazda Motor Corp',
#        '    Mitsubishi Motors Corp', '    Nissan Motor Co Ltd',
#        '    Subaru Corp', '    Tesla Inc', '    Toyota Motor Corp',
#        '    Volkswagen AG'],
#       dtype='object', name='Description')

# %%
cars_df.columns
# Out:
# Index(['date', 'Audi', 'BMW', 'Mini', 'Mercedes Benz', 'Mitsubishi Fuso',
#        'FCA', 'Honda Group', 'Hyundai', 'Isuzu', 'Jaguar Land Rover', 'Kia',
#        'Mazda', 'Mitsubishi', 'Nissan', 'Porsche', 'Subaru', 'Tesla',
#        'Toyota Group', 'Volkswagen', 'Volvo', 'year', 'month', 'datetime'],
#       dtype='object')

# %%
merged_df_ratios.head()
# Out:
# Description      AUDI AG      Bayerische Motoren Werke AG      Daimler AG  \
# variable
# 2004 Q2              NaN                        11.882353             NaN
# 2004 Q3              NaN                        10.659164       13.498982
# 2004 Q4              NaN                         9.969970       14.275304
# 2005 Q1              NaN                        10.513514       14.794872
# 2005 Q2              NaN                        11.369369       13.440000
#
# Description      Fiat Chrysler Automobiles NV      Ford Motor Co  \
# variable
# 2004 Q2                                   NaN           6.561845
# 2004 Q3                                   NaN           5.564356
# 2004 Q4                                   NaN           6.938389
# 2005 Q1                                   NaN           6.950920
# 2005 Q2                                   NaN           6.872483
#
# Description      General Motors Co      Honda Motor Co Ltd  \
# variable
# ...

# %%
merged_df_ratios = merged_df_ratios.reset_index()
merged_df_ratios["Year"] = merged_df_ratios["variable"].apply(lambda x: x.split()[0])
merged_df_ratios["Quarter"] = merged_df_ratios["variable"].apply(lambda x: x.split()[1])
merged_df_ratios.head()
# Out:
# Description variable      AUDI AG      Bayerische Motoren Werke AG  \
# 0            2004 Q2          NaN                        11.882353
# 1            2004 Q3          NaN                        10.659164
# 2            2004 Q4          NaN                         9.969970
# 3            2005 Q1          NaN                        10.513514
# 4            2005 Q2          NaN                        11.369369
#
# Description      Daimler AG      Fiat Chrysler Automobiles NV  \
# 0                       NaN                               NaN
# 1                 13.498982                               NaN
# 2                 14.275304                               NaN
# 3                 14.794872                               NaN
# 4                 13.440000                               NaN
#
# Description      Ford Motor Co      General Motors Co      Honda Motor Co Ltd  \
# 0                     6.561845                    NaN               10.475792
# ...

# %%
def quart(x):
    if(x=='Q1'):
        return(3)
    elif(x=='Q2'):
        return(6)
    elif(x=='Q3'):
        return(9)
    elif(x=='Q4'):
        return(12)
    
merged_df_ratios["Month"] = merged_df_ratios["Quarter"].apply(lambda x: quart(x))
merged_df_ratios.head()
# Out:
# Description variable      AUDI AG      Bayerische Motoren Werke AG  \
# 0            2004 Q2          NaN                        11.882353
# 1            2004 Q3          NaN                        10.659164
# 2            2004 Q4          NaN                         9.969970
# 3            2005 Q1          NaN                        10.513514
# 4            2005 Q2          NaN                        11.369369
#
# Description      Daimler AG      Fiat Chrysler Automobiles NV  \
# 0                       NaN                               NaN
# 1                 13.498982                               NaN
# 2                 14.275304                               NaN
# 3                 14.794872                               NaN
# 4                 13.440000                               NaN
#
# Description      Ford Motor Co      General Motors Co      Honda Motor Co Ltd  \
# 0                     6.561845                    NaN               10.475792
# ...
